# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
class Noeud:
    
    def __init__(self, coor,name):
        self.coor = coor
        self.name=name
        self.chemins=[]
    def addChemin(self,chemin):
        self.chemins.append(chemin)
class Chemin:
    def __init__(self,cout,depart,arriver):
        self.cout=cout
        self.depart=depart
        self.arriver=arriver
class Graphe:
    def __init__(self,noeuds):
        self.noeuds=noeuds
    def plot(self):
        for i in range(len(self.noeuds)):
            for j in range(i,len(self.noeuds)):
                
                x=[self.noeuds[i].coor[0],self.noeuds[j].coor[0]]
                y=[self.noeuds[i].coor[1],self.noeuds[j].coor[1]]
                plt.plot(x,y,marker = 'o')
                
                cout=math.dist(self.noeuds[i].coor,self.noeuds[j].coor)
                self.noeuds[i].addChemin(Chemin(cout,self.noeuds[i],self.noeuds[j]))
                self.noeuds[j].addChemin(Chemin(cout,self.noeuds[j],self.noeuds[i]))
        plt.show()
        
        def circuitHamiltonien(self)

# %%
listNoeuds=[]

for i in range(4):
    randX=random.randint(1,100)
    randY=random.randint(1,100)
    noeud=Noeud([randX,randY],i)
    listNoeuds.append(noeud)

firstGraphe=Graphe(listNoeuds)
firstGraphe.plot()
